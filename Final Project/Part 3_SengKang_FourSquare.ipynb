# %% [markdown]
# **PART 3**
# Exploring and clustering the neighborhoods in Sengkang

# %% [markdown]
# # Introduction
# I will be using the Foursquare API to explore the nearby venues in SengKang
# <br>
# I shall use the Folium library to visualize the various venues in Sengkang

# %%
# Importing the required libraries
import numpy as np 
import pandas as pd 

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# library to handle JSON files
import json 


# convert an address into latitude and longitude values
from geopy.geocoders import Nominatim 
GeoLocator = Nominatim(user_agent='My-IBMNotebook')

 # library to handle requests and transform JSON file into a Pandas DataFrame
import requests 
from pandas.io.json import json_normalize 

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# map rendering library
import folium

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# Retrieving the data that was cleaned up in Part 2 of this assignmentHDB_2/Sengkang_Part_2.csv")
sk_neighborhoods = pd.read_csv("C:/Users/Buck Hui/Documents/IBM Data Science/^ Capstone Project/HDB_2/Sengkang_Part_2.csv")
sk_neighborhoods.head()
# Out:
#     Borough    Neighbourhood    Latitude  Longitude
# 0  SENGKANG  ANCHORVALE CRES  103.889866   1.397981
# 1  SENGKANG    ANCHORVALE DR  103.891536   1.390196
# 2  SENGKANG  ANCHORVALE LANE  103.884412   1.392105
# 3  SENGKANG  ANCHORVALE LINK  103.890182   1.392388
# 4  SENGKANG    ANCHORVALE RD  103.888536   1.394942

# %%
sk_neighborhoods.shape
# Out:
# (29, 4)

# %%
address = 'Sengkang, Singapore'

geolocator = Nominatim(user_agent="sengkang_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Sengkang, Singapore are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Sengkang, Singapore are 1.3919236499999998, 103.89549093760694.

# %%
# create map of SK using latitude and longitude values
map_sk = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, borough, neighborhood in zip(sk_neighborhoods['Latitude'], sk_neighborhoods['Longitude'], sk_neighborhoods['Borough'], sk_neighborhoods['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#87cefa',
        fill_opacity=0.5,
        parse_html=False).add_to(map_sk)
    
map_sk
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sk_data = sk_neighborhoods[sk_neighborhoods['Borough'].str.contains("SENGKANG")].reset_index(drop=True)
print(sk_data.shape)
sk_data.head()
# Out:
# (29, 4)
#     Borough    Neighbourhood    Latitude  Longitude
# 0  SENGKANG  ANCHORVALE CRES  103.889866   1.397981
# 1  SENGKANG    ANCHORVALE DR  103.891536   1.390196
# 2  SENGKANG  ANCHORVALE LANE  103.884412   1.392105
# 3  SENGKANG  ANCHORVALE LINK  103.890182   1.392388
# 4  SENGKANG    ANCHORVALE RD  103.888536   1.394942

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(sk_neighborhoods['Borough'].unique()),
        sk_neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 1 boroughs and 29 neighborhoods.

# %%
CLIENT_ID = 'redacted for confidentiality' # your Foursquare ID
CLIENT_SECRET = 'redacted for confidentiality' # your Foursquare Secret
VERSION = '20201115'
LIMIT = 30

# %%
neighborhood_latitude = 1.3919236499999998 # neighborhood latitude value
neighborhood_longitude = 103.89549093760694 # neighborhood longitude value

#1.3919236499999998, 103.89549093760694.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=K3FRWPPRTT2O4WLNKQGL3VHKEBT5DFBMHKNAWJIR4LSCOC2Q&client_secret=UAGPJ0GYP1TWL03VKXW3COJQ0SXEUOIA40LOGWKJDSTTFRXG&v=20201115&ll=1.3919236499999998,103.89549093760694&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fc4b53d72ff46632005f1fe'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Sengkang',
#   'headerFullLocation': 'Sengkang, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 29,
#   'suggestedBounds': {'ne': {'lat': 1.3964236545000044,
#     'lng': 103.89998386583989},
#    'sw': {'lat': 1.3874236454999953, 'lng': 103.89099800937399}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c90306498e61437fbdac58',
#        'name': 'Maki-san',
#        'location': {'address': '#01-45, Compass One',
#         'crossStreet': '1 Sengkang Sq.',
#         'lat': 1.3923110109254946,
#         'lng': 103.8949687237786,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3923110109254946,
#           'lng': 103.8949687237786}],
#         'distance': 72,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Sengkang',
#         'state': 'North East Community Development Region',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-45, Compass One (1 Sengkang Sq.)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c90306498e61437fbdac58-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c96c8c498eae8bcd4004f6',
#        'name': 'Ya Kun Family Cafe',
#        'location': {'address': '#01-37, Compass One',
#         'crossStreet': '1 Sengkang Sq.',
#         'lat': 1.3919032285633344,
#         'lng': 103.89491278601824,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3919032285633344,
#           'lng': 103.89491278601824}],
#         'distance': 64,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Sengkang',
#         'state': 'North East Community Development Region',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-37, Compass One (1 Sengkang Sq.)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c96c8c498eae8bcd4004f6-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c7977c498e1cd1373e4552',
#        'name': 'Starbucks',
#        'location': {'address': '1 Sengkang Square, #B1-L4',
#         'lat': 1.392367316242362,
#         'lng': 103.8950180617861,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.392367316242362,
#           'lng': 103.8950180617861}],
#         'distance': 72,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Sengkang Square, #B1-L4',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c7977c498e1cd1373e4552-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '597459c3e679bc300dd7782f',
#        'name': 'Châteraisé',
#        'location': {'address': '#03-39/40/41, Compass One',
#         'crossStreet': '1 Sengkang Sq',
#         'lat': 1.3922447904791313,
#         'lng': 103.89507935934154,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3922447904791313,
#           'lng': 103.89507935934154}],
#         'distance': 58,
#         'postalCode': '541257',
#         'cc': 'SG',
#         'city': 'Sengkang',
#         'state': 'North East Community Development Region',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-39/40/41, Compass One (1 Sengkang Sq)',
#          '541257',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-597459c3e679bc300dd7782f-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57ca7247498e830388b266d6',
#        'name': 'Canton Paradise',
#        'location': {'address': '#03-14, Compass One',
#         'crossStreet': '1 Sengkang Sq.',
#         'lat': 1.3922989240422525,
#         'lng': 103.89512768870073,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3922989240422525,
#           'lng': 103.89512768870073}],
#         'distance': 58,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-14, Compass One (1 Sengkang Sq.)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57ca7247498e830388b266d6-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3b3b52f964a520a47125e3',
#        'name': 'Cold Storage',
#        'location': {'address': '#B1-25, Compass One',
#         'crossStreet': '1 Sengkang Sq.',
#         'lat': 1.3923423744341394,
#         'lng': 103.895036832252,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3923423744341394,
#           'lng': 103.895036832252}],
#         'distance': 68,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'neighborhood': 'Sengkang',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-25, Compass One (1 Sengkang Sq.)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3b3b52f964a520a47125e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6fbcd0f964a52041fb2ce3',
#        'name': 'Sengkang Sculpture Park',
#        'location': {'address': '1 Sengkang Square',
#         'lat': 1.3945493,
#         'lng': 103.89663,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3945493,
#           'lng': 103.89663}],
#         'distance': 318,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Sengkang Square', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d166941735',
#          'name': 'Sculpture Garden',
#          'pluralName': 'Sculpture Gardens',
#          'shortName': 'Sculpture',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6fbcd0f964a52041fb2ce3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57d109e4498e6c37e30e8c2c',
#        'name': 'LeNu 樂牛',
#        'location': {'address': '1 Sengkang Square',
#         'crossStreet': '#03-05',
#         'lat': 1.3924151247455308,
#         'lng': 103.89505243463142,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3924151247455308,
#           'lng': 103.89505243463142}],
#         'distance': 73,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Sengkang',
#         'state': 'North East Community Development Region',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Sengkang Square (#03-05)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57d109e4498e6c37e30e8c2c-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57bad31c498edb849d415f75',
#        'name': 'Subway',
#        'location': {'address': '#01-20, Compass One',
#         'crossStreet': '1 Sengkang Sq.',
#         'lat': 1.3920523981589386,
#         'lng': 103.89533754871836,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3920523981589386,
#           'lng': 103.89533754871836}],
#         'distance': 22,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-20, Compass One (1 Sengkang Sq.)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57bad31c498edb849d415f75-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57fe00cd38fac6d96f955ce8',
#        'name': 'kopitiam compassone (Kopitiam)',
#        'location': {'address': '#04-11, Compass One',
#         'crossStreet': '1 Sengkang Sq',
#         'lat': 1.3922727763153966,
#         'lng': 103.89511364873853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3922727763153966,
#           'lng': 103.89511364873853}],
#         'distance': 57,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#04-11, Compass One (1 Sengkang Sq)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57fe00cd38fac6d96f955ce8-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c902d9498e411720c9eed7',
#        'name': "Jack's Place",
#        'location': {'address': '#04-07, Compass One',
#         'crossStreet': '1 Sengkang Sq.',
#         'lat': 1.3922495503703987,
#         'lng': 103.89507989664473,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3922495503703987,
#           'lng': 103.89507989664473}],
#         'distance': 58,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'neighborhood': 'Sengkang',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#04-07, Compass One (1 Sengkang Sq.)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c902d9498e411720c9eed7-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57cc11d2cd1043c5b748f744',
#        'name': "McDonald's",
#        'location': {'address': '1 Sengkang Square #B1-13 Compass One',
#         'crossStreet': '1 Compass Sq',
#         'lat': 1.392464658740058,
#         'lng': 103.89517472645691,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.392464658740058,
#           'lng': 103.89517472645691}],
#         'distance': 69,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Sengkang Square #B1-13 Compass One (1 Compass Sq)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57cc11d2cd1043c5b748f744-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8913dff964a5207f1b32e3',
#        'name': 'Kopitiam Square',
#        'location': {'address': '10 Sengkang Sq.',
#         'lat': 1.3914116301112787,
#         'lng': 103.89375257032209,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3914116301112787,
#           'lng': 103.89375257032209}],
#         'distance': 201,
#         'postalCode': '544829',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['10 Sengkang Sq.', '544829', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8913dff964a5207f1b32e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca40a1a750ca09375631e67',
#        'name': "Uncle Tony's Tuckshop",
#        'location': {'address': '#01-05 Sengkang Community Hub',
#         'crossStreet': '2 Sengkang Square',
#         'lat': 1.3931002373129582,
#         'lng': 103.8943565364528,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3931002373129582,
#           'lng': 103.8943565364528}],
#         'distance': 181,
#         'postalCode': '545025',
#         'cc': 'SG',
#         'neighborhood': 'Sengkang',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-05 Sengkang Community Hub (2 Sengkang Square)',
#          '545025',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca40a1a750ca09375631e67-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c7975f498e8149c9c530d8',
#        'name': 'KFC',
#        'location': {'address': 'Compass One',
#         'crossStreet': '1 Sengkang Square',
#         'lat': 1.3921356,
#         'lng': 103.895355,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3921356,
#           'lng': 103.895355}],
#         'distance': 28,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'neighborhood': 'Sengkang',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Compass One (1 Sengkang Square)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c7975f498e8149c9c530d8-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0bd279f964a520ec3323e3',
#        'name': 'Compass One',
#        'location': {'address': '1 Sengkang Sq.',
#         'lat': 1.3923495643750352,
#         'lng': 103.89506811317483,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3923495643750352,
#           'lng': 103.89506811317483}],
#         'distance': 66,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Sengkang Sq.', '545078', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0bd279f964a520ec3323e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57ca85c5498e1f871a5edbf4',
#        'name': 'The Coffee Bean & Tea Leaf',
#        'location': {'address': '#01-23 Compass One',
#         'crossStreet': '1 Sengkang Sq.',
#         'lat': 1.3923470889259757,
#         'lng': 103.89518845507969,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3923470889259757,
#           'lng': 103.89518845507969}],
#         'distance': 57,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-23 Compass One (1 Sengkang Sq.)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57ca85c5498e1f871a5edbf4-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57ecec8c498ed9eb3c8a8ec3',
#        'name': 'Burger King',
#        'location': {'address': '#B1-14/14A, Compass One',
#         'crossStreet': '1 Sengkang Sq',
#         'lat': 1.3924458891275455,
#         'lng': 103.89519604623995,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3924458891275455,
#           'lng': 103.89519604623995}],
#         'distance': 66,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-14/14A, Compass One (1 Sengkang Sq)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57ecec8c498ed9eb3c8a8ec3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1854baf964a52000d123e3',
#        'name': 'Sengkang MRT/LRT Interchange (NE16/STC)',
#        'location': {'address': '5 Sengkang Sq',
#         'lat': 1.3915302795988986,
#         'lng': 103.895384486157,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3915302795988986,
#           'lng': 103.895384486157}],
#         'distance': 45,
#         'postalCode': '545062',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['5 Sengkang Sq', '545062', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fd931735',
#          'name': 'Metro Station',
#          'pluralName': 'Metro Stations',
#          'shortName': 'Metro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1854baf964a52000d123e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba82f61f964a52013d039e3',
#        'name': 'Sengkang Bus Interchange',
#        'location': {'address': '13 Sengkang Sq',
#         'lat': 1.3917346708177383,
#         'lng': 103.89551967429388,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3917346708177383,
#           'lng': 103.89551967429388}],
#         'distance': 21,
#         'postalCode': '545077',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['13 Sengkang Sq', '545077', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba82f61f964a52013d039e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57cbae3f498edb2720b8f4b2',
#        'name': 'Challenger',
#        'location': {'lat': 1.3923314755382747,
#         'lng': 103.89511939024682,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3923314755382747,
#           'lng': 103.89511939024682}],
#         'distance': 61,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['545078', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57cbae3f498edb2720b8f4b2-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cac644a14c337044383ef3b',
#        'name': 'SBS Transit: Sengkang LRT (SKLRT)',
#        'location': {'lat': 1.391598032214857,
#         'lng': 103.8954706383458,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.391598032214857,
#           'lng': 103.8954706383458}],
#         'distance': 36,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fc931735',
#          'name': 'Light Rail Station',
#          'pluralName': 'Light Rail Stations',
#          'shortName': 'Light Rail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cac644a14c337044383ef3b-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9579dc94a0236a22f29612',
#        'name': 'Ness',
#        'location': {'address': 'Compass Point',
#         'lat': 1.390403,
#         'lng': 103.896237,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.390403,
#           'lng': 103.896237}],
#         'distance': 188,
#         'postalCode': '545075',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Compass Point', '545075', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d108951735',
#          'name': "Women's Store",
#          'pluralName': "Women's Stores",
#          'shortName': "Women's Store",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9579dc94a0236a22f29612-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57cbafeb498e5242eab3c39a',
#        'name': 'Crocs',
#        'location': {'lat': 1.3920999,
#         'lng': 103.89502,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3920999,
#           'lng': 103.89502}],
#         'distance': 55,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'neighborhood': 'Sengkang',
#         'country': 'Singapore',
#         'formattedAddress': ['545078', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d107951735',
#          'name': 'Shoe Store',
#          'pluralName': 'Shoe Stores',
#          'shortName': 'Shoes',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57cbafeb498e5242eab3c39a-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d7b26242deabf000811093d',
#        'name': 'Xing Fu Tang',
#        'location': {'address': '1 Sengkang Square (Compass One, #B1-10)',
#         'lat': 1.3917278,
#         'lng': 103.89472,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3917278,
#           'lng': 103.89472}],
#         'distance': 88,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'neighborhood': 'Sengkang',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Sengkang Square (Compass One, #B1-10)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d7b26242deabf000811093d-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c09f4023c70b71367e8275b',
#        'name': 'Kawaii Nails',
#        'location': {'address': 'Rivervale Plaza',
#         'crossStreet': '118 Rivervale Drive',
#         'lat': 1.3925561823866128,
#         'lng': 103.89460716280244,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3925561823866128,
#           'lng': 103.89460716280244}],
#         'distance': 120,
#         'postalCode': '540118',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Rivervale Plaza (118 Rivervale Drive)',
#          '540118',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c09f4023c70b71367e8275b-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c81a51498e61091cfd8e10',
#        'name': "Swensen's",
#        'location': {'address': '#B1-16, Compass One',
#         'crossStreet': '1 Sengkang Sq.',
#         'lat': 1.3923781125141068,
#         'lng': 103.89517558396439,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3923781125141068,
#           'lng': 103.89517558396439}],
#         'distance': 61,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-16, Compass One (1 Sengkang Sq.)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c81a51498e61091cfd8e10-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c05dedd5753c928072a3af1',
#        'name': 'The Face Shop',
#        'location': {'address': '#01-47/48, Compass Point',
#         'crossStreet': '1 Sengkang Sq.',
#         'lat': 1.3931838917398247,
#         'lng': 103.89762694472628,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3931838917398247,
#           'lng': 103.89762694472628}],
#         'distance': 276,
#         'postalCode': '545078',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-47/48, Compass Point (1 Sengkang Sq.)',
#          '545078',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c05dedd5753c928072a3af1-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb60163e262b60ce2cb6be0',
#        'name': 'STARLIGHT',
#        'location': {'lat': 1.393445,
#         'lng': 103.899074,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.393445,
#           'lng': 103.899074}],
#         'distance': 433,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb60163e262b60ce2cb6be0-28'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# <ipython-input-13-561c05f0fdd1>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   nearby_venues = json_normalize(venues) # flatten JSON
#                  name          categories       lat         lng
# 0            Maki-san    Sushi Restaurant  1.392311  103.894969
# 1  Ya Kun Family Cafe                Café  1.391903  103.894913
# 2           Starbucks         Coffee Shop  1.392367  103.895018
# 3          Châteraisé              Bakery  1.392245  103.895079
# 4     Canton Paradise  Chinese Restaurant  1.392299  103.895128

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 29 venues were returned by Foursquare.

# %%
print(nearby_venues.shape)
nearby_venues.head()
# Out:
# (29, 4)
#                  name          categories       lat         lng
# 0            Maki-san    Sushi Restaurant  1.392311  103.894969
# 1  Ya Kun Family Cafe                Café  1.391903  103.894913
# 2           Starbucks         Coffee Shop  1.392367  103.895018
# 3          Châteraisé              Bakery  1.392245  103.895079
# 4     Canton Paradise  Chinese Restaurant  1.392299  103.895128

# %% [markdown]
# # Count of venues were returned for each Borough

# %%
nearby_venues.groupby('categories').count()
# Out:
#                       name  lat  lng
# categories
# Asian Restaurant         1    1    1
# Bakery                   1    1    1
# Bubble Tea Shop          1    1    1
# Bus Station              1    1    1
# Café                     1    1    1
# Chinese Restaurant       1    1    1
# Coffee Shop              2    2    2
# Cosmetics Shop           2    2    2
# Electronics Store        1    1    1
# Fast Food Restaurant     3    3    3
# Food Court               2    2    2
# Light Rail Station       1    1    1
# Metro Station            1    1    1
# Noodle House             1    1    1
# Park                     1    1    1
# Restaurant               1    1    1
# Sandwich Place           1    1    1
# Sculpture Garden         1    1    1
# Shoe Store               1    1    1
# Shopping Mall            1    1    1
# Steakhouse               1    1    1
# Supermarket              1    1    1
# Sushi Restaurant         1    1    1
# Women's Store            1    1    1

# %% [markdown]
# # How many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(nearby_venues['categories'].unique())))
# Out:
# There are 24 uniques categories.

# %% [markdown]
# # To visualize the clusters

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)


# add markers to the map
markers_colors = []
for lat, lng, cat in zip(nearby_venues['lat'], nearby_venues['lng'], nearby_venues['categories']):
        folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
